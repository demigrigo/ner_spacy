# %% [markdown]
# This notebook is an attempt to use NER methods in a text of Auden

# %%
#import the txt file
# !python -m spacy download en_core_web_sm
# Out:
# 2023-06-29 08:43:57.079351: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 08:43:58.031678: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-29 08:43:59.652681: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(open('Years_in_Austria.txt').read())

# %%
print([(w.text, w.pos_) for w in doc]) #this prints out the NER in all Years in Austria
# Out:
# [('The', 'DET'), ('Years', 'PROPN'), ('in', 'ADP'), ('Austria', 'PROPN'), ('.', 'PUNCT'), ('\n', 'SPACE'), ('Half', 'DET'), ('an', 'DET'), ('hour', 'NOUN'), ('from', 'ADP'), ('the', 'DET'), ('outskirts', 'NOUN'), ('of', 'ADP'), (' ', 'SPACE'), ('Vienna', 'PROPN'), (' ', 'SPACE'), ('an', 'DET'), ('invisible', 'ADJ'), ('\n', 'SPACE'), ('thread', 'NOUN'), ('bisect', 'NOUN'), ('x', 'SYM'), ('s', 'VERB'), ('the', 'DET'), ('motorway', 'NOUN'), ('.', 'PUNCT'), (' ', 'SPACE'), ('It', 'PRON'), ('leads', 'VERB'), ('from', 'ADP'), ('the', 'DET'), ('church', 'NOUN'), ('which', 'PRON'), ('\n', 'SPACE'), ('lies', 'VERB'), ('to', 'ADP'), ('the', 'DET'), ('north', 'NOUN'), (',', 'PUNCT'), ('more', 'ADV'), ('accurately', 'ADV'), ('speaking', 'VERB'), ('from', 'ADP'), ('the', 'DET'), ('churchyard', 'ADJ'), (',', 'PUNCT'), ('\n', 'SPACE'), ('disregards', 'VERB'), ('entirely', 'ADV'), ('the', 'DET'), ('traffic', 'NOUN'), ('as', 'SCONJ'), ('it', 'PRON'), ('thunders', 'VERB'), ('to', 'ADP'), ('and', 'CCON
# ...

# %% [markdown]
# Let's tidy up our space

# %%
import nltk
from nltk.collocations import *

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize

# %%
austria = open('Years_in_Austria.txt', 'r') #we read the file and seperate lines
for line in austria:
    print(line.strip())
# Out:
# The Years in Austria .
# Half an hour from the outskirts of  Vienna  an invisible
# thread bisect x s the motorway.  It leads from the church which
# lies to the north, more accurately speaking from the churchyard,
# disregards entirely the traffic as it thunders to and from  the
# capital , wriggles across a field to the south, passes a small
# house which was once a garage.  Up a steep path, plum trees
# on one side and apple trees on the other, through a wicket
# gate, and now the thread, which has turned neither to right nor
# left, has reached its objective:  a long, low house, more an
# extended workman's cottage.  Originally, the address was
# Hinterhol 6 z 6 ;   later, the lane up from the village on the other
# side was renamed  Auden- A Strasse .  This thread or unseen line joins
# the places where  Auden  prayed, sang (flat) and  was buried , and
# the place where he lived, and to me it is tangible reality,
# unfailingly sensed at each frequent crossing.  Partly it is
# ...

# %%
filepath = nltk.data.find('/content/Years_in_Austria.txt')
textfile = open(filepath, 'r').read()

# %%
textfile #we are able to manipulate the text
# Out:
# 'The Years in Austria . \nHalf an hour from the outskirts of  Vienna  an invisible \nthread bisect x s the motorway.  It leads from the church which \nlies to the north, more accurately speaking from the churchyard, \ndisregards entirely the traffic as it thunders to and from  the \ncapital , wriggles across a field to the south, passes a small \nhouse which was once a garage.  Up a steep path, plum trees \non one side and apple trees on the other, through a wicket \ngate, and now the thread, which has turned neither to right nor \nleft, has reached its objective:  a long, low house, more an \nextended workman\'s cottage.  Originally, the address was \nHinterhol 6 z 6 ;   later, the lane up from the village on the other \nside was renamed  Auden- A Strasse .  This thread or unseen line joins \nthe places where  Auden  prayed, sang (flat) and  was buried , and \nthe place where he lived, and to me it is tangible reality, \nunfailingly sensed at each frequent crossing.  Partly it is \n
# ...

# %%
tokenlist = word_tokenize(textfile)
print(len(tokenlist))
# Out:
# 22358

# %%
tokenlist #the tokens of the text
# Out:
# ['The',
#  'Years',
#  'in',
#  'Austria',
#  '.',
#  'Half',
#  'an',
#  'hour',
#  'from',
#  'the',
#  'outskirts',
#  'of',
#  'Vienna',
#  'an',
#  'invisible',
#  'thread',
#  'bisect',
#  'x',
#  's',
#  'the',
#  'motorway',
#  '.',
#  'It',
#  'leads',
#  'from',
#  'the',
#  'church',
#  'which',
#  'lies',
#  'to',
#  'the',
#  'north',
#  ',',
#  'more',
#  'accurately',
#  'speaking',
#  'from',
#  'the',
#  'churchyard',
#  ',',
#  'disregards',
#  'entirely',
#  'the',
#  'traffic',
#  'as',
#  'it',
#  'thunders',
#  'to',
#  'and',
#  'from',
#  'the',
#  'capital',
#  ',',
#  'wriggles',
#  'across',
#  'a',
#  'field',
#  'to',
#  'the',
#  'south',
#  ',',
#  'passes',
#  'a',
#  'small',
#  'house',
#  'which',
#  'was',
#  'once',
#  'a',
#  'garage',
#  '.',
#  'Up',
#  'a',
#  'steep',
#  'path',
#  ',',
#  'plum',
#  'trees',
#  'on',
#  'one',
#  'side',
#  'and',
#  'apple',
#  'trees',
#  'on',
#  'the',
#  'other',
#  ',',
#  'through',
#  'a',
# ...

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
stop_words = set(stopwords.words("english"))

# %%
tokenlist_lower = []
for token in tokenlist:
    tokenlist_lower.append(token.lower())
print(tokenlist_lower) #we make all words lowercase
# Out:
# ['the', 'years', 'in', 'austria', '.', 'half', 'an', 'hour', 'from', 'the', 'outskirts', 'of', 'vienna', 'an', 'invisible', 'thread', 'bisect', 'x', 's', 'the', 'motorway', '.', 'it', 'leads', 'from', 'the', 'church', 'which', 'lies', 'to', 'the', 'north', ',', 'more', 'accurately', 'speaking', 'from', 'the', 'churchyard', ',', 'disregards', 'entirely', 'the', 'traffic', 'as', 'it', 'thunders', 'to', 'and', 'from', 'the', 'capital', ',', 'wriggles', 'across', 'a', 'field', 'to', 'the', 'south', ',', 'passes', 'a', 'small', 'house', 'which', 'was', 'once', 'a', 'garage', '.', 'up', 'a', 'steep', 'path', ',', 'plum', 'trees', 'on', 'one', 'side', 'and', 'apple', 'trees', 'on', 'the', 'other', ',', 'through', 'a', 'wicket', 'gate', ',', 'and', 'now', 'the', 'thread', ',', 'which', 'has', 'turned', 'neither', 'to', 'right', 'nor', 'left', ',', 'has', 'reached', 'its', 'objective', ':', 'a', 'long', ',', 'low', 'house', ',', 'more', 'an', 'extended', 'workman', "'s", 'cottage', '.', 'orig
# ...

# %%
filtered_sentence = [w for w in tokenlist_lower if not w.lower() in stop_words]
#with no lower case conversion
filtered_sentence = []

for w in tokenlist_lower:
    if w not in stop_words:
        filtered_sentence.append(w)

print(tokenlist_lower)
print(filtered_sentence) #we removed stop words
# Out:
# ['the', 'years', 'in', 'austria', '.', 'half', 'an', 'hour', 'from', 'the', 'outskirts', 'of', 'vienna', 'an', 'invisible', 'thread', 'bisect', 'x', 's', 'the', 'motorway', '.', 'it', 'leads', 'from', 'the', 'church', 'which', 'lies', 'to', 'the', 'north', ',', 'more', 'accurately', 'speaking', 'from', 'the', 'churchyard', ',', 'disregards', 'entirely', 'the', 'traffic', 'as', 'it', 'thunders', 'to', 'and', 'from', 'the', 'capital', ',', 'wriggles', 'across', 'a', 'field', 'to', 'the', 'south', ',', 'passes', 'a', 'small', 'house', 'which', 'was', 'once', 'a', 'garage', '.', 'up', 'a', 'steep', 'path', ',', 'plum', 'trees', 'on', 'one', 'side', 'and', 'apple', 'trees', 'on', 'the', 'other', ',', 'through', 'a', 'wicket', 'gate', ',', 'and', 'now', 'the', 'thread', ',', 'which', 'has', 'turned', 'neither', 'to', 'right', 'nor', 'left', ',', 'has', 'reached', 'its', 'objective', ':', 'a', 'long', ',', 'low', 'house', ',', 'more', 'an', 'extended', 'workman', "'s", 'cottage', '.', 'orig
# ...

# %%
print(len(filtered_sentence)) #list of all words without stop words
# Out:
# 12548

# %%
new_words= [word for word in filtered_sentence if word.isalnum()]
print(new_words) #this is a list with all words from years in austria without punctuation
# Out:
# ['years', 'austria', 'half', 'hour', 'outskirts', 'vienna', 'invisible', 'thread', 'bisect', 'x', 'motorway', 'leads', 'church', 'lies', 'north', 'accurately', 'speaking', 'churchyard', 'disregards', 'entirely', 'traffic', 'thunders', 'capital', 'wriggles', 'across', 'field', 'south', 'passes', 'small', 'house', 'garage', 'steep', 'path', 'plum', 'trees', 'one', 'side', 'apple', 'trees', 'wicket', 'gate', 'thread', 'turned', 'neither', 'right', 'left', 'reached', 'objective', 'long', 'low', 'house', 'extended', 'workman', 'cottage', 'originally', 'address', 'hinterhol', '6', 'z', '6', 'later', 'lane', 'village', 'side', 'renamed', 'strasse', 'thread', 'unseen', 'line', 'joins', 'places', 'auden', 'prayed', 'sang', 'flat', 'buried', 'place', 'lived', 'tangible', 'reality', 'unfailingly', 'sensed', 'frequent', 'crossing', 'partly', 'alwa', 'ys', 'direction', 'arrived', 'mistrustful', 'narrow', 'lane', 'lies', 'along', 'top', 'garden', 'leads', 'wood', 'small', 'clearing', 'floored', 't
# ...

# %%
from collections import Counter
counts = Counter(new_words)
print(counts) #we print out how many times each word appears
# Out:
# Counter({'auden': 140, 'one': 90, 'would': 73, 'chester': 63, 'e': 48, 'could': 46, 'time': 41, 'said': 38, 'much': 37, 'people': 34, 'kirchstetten': 33, 'like': 31, 'poet': 29, 'poem': 29, 'never': 28, 'say': 27, 'german': 27, 'austria': 26, 'world': 26, 'f': 25, 'two': 25, 'must': 25, 'asked': 24, 'way': 24, 'came': 24, 'may': 24, 'vienna': 23, 'years': 22, 'austrian': 22, 'english': 21, 'know': 21, 'think': 21, 'come': 21, 'even': 21, 'wystan': 19, 'r': 19, 'work': 19, 'n': 19, 'man': 19, 'w': 19, 'left': 18, 'new': 18, 'house': 17, 'long': 17, 'later': 17, 'car': 17, 'poetry': 17, 'great': 17, 'q': 17, 'c': 17, 'artistic': 17, 'place': 16, 'back': 16, 'without': 16, 'might': 16, 'well': 16, 'take': 15, 'make': 15, 'little': 15, 'quite': 15, 'day': 15, 'first': 15, 'good': 15, 'literature': 15, 'read': 15, 'made': 15, 'though': 15, 'art': 15, 'right': 14, 'write': 14, 'g': 14, 'subject': 14, 'went': 14, 'weinheber': 14, 'political': 14, 'kallman': 14, 'days': 13, 'us': 13, 'door':
# ...

# %%
new=' '.join(new_words) #we turned list into str so that we can use the NER

# %%
print(new)
# Out:
# years austria half hour outskirts vienna invisible thread bisect x motorway leads church lies north accurately speaking churchyard disregards entirely traffic thunders capital wriggles across field south passes small house garage steep path plum trees one side apple trees wicket gate thread turned neither right left reached objective long low house extended workman cottage originally address hinterhol 6 z 6 later lane village side renamed strasse thread unseen line joins places auden prayed sang flat buried place lived tangible reality unfailingly sensed frequent crossing partly alwa ys direction arrived mistrustful narrow lane lies along top garden leads wood small clearing floored times sticky mud car turned seemed preferable anyway became habit take cart track field ruts depth left undercarriage slide along plateau coarse grass leave car garage plod orchard accepting risk slithering path right walking next woodshed time time today risk savaged dog earlier days account ones presenc
# ...

# %%
import spacy
from spacy import displacy

# %%
NER = spacy.load("en_core_web_sm")

# %%
new2= NER(new) #perform NER in Years in Austria

# %%
for word in new2.ents:
  print(word.text,word.label_)
# Out:
# years DATE
# half hour TIME
# vienna PERSON
# one CARDINAL
# 6 z TIME
# auden PERSON
# today DATE
# earlier days DATE
# fug ORG
# austrian NORP
# two CARDINAL
# auden PERSON
# years DATE
# one CARDINAL
# austrian NORP
# two CARDINAL
# english NORP
# thirteen CARDINAL
# auden surprised PERSON
# auden PERSON
# sunday DATE
# weekly DATE
# wystan auden know PERSON
# li PERSON
# one CARDINAL
# evening TIME
# obsession wystan ORG
# auden PERSON
# german NORP
# austrians NORP
# one two CARDINAL
# wystan NORP
# chris daughter PERSON
# hugo von hofmannsthal christiane zimmer PERSON
# auden new york ORG
# gerty von hofmannsthal PERSON
# 1929 DATE
# nazis NORP
# overran austria PERSON
# fifties DATE
# vienna GPE
# arabella octavian PERSON
# pri ORG
# diana cooper PERSON
# prielau house PERSON
# musulin LOC
# half hour TIME
# auden 1958 chance ORG
# auden neighbour demurred PERSON
# 1959 DATE
# one CARDINAL
# one CARDINAL
# 5 CARDINAL
# whitsunday DATE
# seitz ORG
# auden PERSON
# ...

# %%
displacy.render(new2, style="ent", jupyter=True) #we display with color
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  austria
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  outskirts
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vienna
# ...

# %% [markdown]
# Let's train the Spacy Model

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
corpus = []

doc = nlp(new) #the old string file
for sent in doc.sents:
    corpus.append(sent.text)

nlp = spacy.blank("en")

ruler = nlp.add_pipe("entity_ruler")

patterns = [
                {"label": "GPE", "pattern": "vienna"}
            ]

ruler.add_patterns(patterns)

TRAIN_DATA = []
for sentence in corpus:
    doc = nlp(sentence)
    entities = []

    for ent in doc.ents:
        entities.append([ent.start_char, ent.end_char, ent.label_])
    TRAIN_DATA.append([sentence, {"entities": entities}])

print (TRAIN_DATA)
# Out:
# [['years austria half hour outskirts vienna invisible thread bisect x motorway leads church lies north accurately speaking churchyard disregards entirely traffic thunders capital wriggles across field south passes small house garage steep path plum trees one side apple trees wicket gate thread turned neither right left reached objective long low house extended workman cottage originally address hinterhol 6 z 6 later lane village side renamed strasse thread unseen line joins places auden prayed sang flat buried place lived tangible reality unfailingly sensed frequent crossing partly alwa ys direction arrived mistrustful narrow lane lies along top garden leads wood small clearing floored times sticky mud car turned seemed preferable anyway became habit take cart track field ruts depth left undercarriage slide along plateau coarse grass leave car garage plod orchard accepting risk slithering path', {'entities': [[34, 40, 'GPE']]}], ['right walking next woodshed time time today risk sava
# ...

# %%
spacy.displacy.render(doc, style="ent", jupyter=True) #we make sure that the entity chester is identified as person #we saw that with tokenization NER doesnt work well
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">tuesday impossible people england notified leaving final date moment decision conveniently created natural pause clarks undertook send telegrams driven p post office frau strobl stood chester came asked carry discussions funeral arrangements may r frau seitz said could bear must try hold others check would agree anything said right really said full brim tranquillisers needed bit peace hugged warmly together mayor left frau seitz car drove house end village sort talk one whip v genda took time chester realised compared style austrian village carries senior citizens grave asked consent tall order would voluntary fire brigade gamekeepers ancient ritual wishes good hunting fields elysium bellowed open grave linesmen local railway representatives local football club marksmen association et al since none would would fed afterwards mayor wanted brass band felt wystan would amused might watching even 
# ...

# %% [markdown]
# Another approach- Train a model

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(open('Years_in_Austria.txt').read())

print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The Years in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Half an hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  from the outskirts of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vienna
# ...

# %%
# !pip install spacy[transformers]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.8/190.8 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 83.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 119.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 87.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !python3 -m spacy download en_core_web_trf
# Out:
# 2023-06-29 08:45:21.882421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.3/460.3 MB 3.4 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
# !pip3 install -U spacy[cuda111,transformers]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 48.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.2/101.2 MB 9.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.3
#     Uninstalling spacy-3.5.3:
#       Successfully uninstalled spacy-3.5.3
# ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
corpus = []

doc = nlp(doc)
for sent in doc.sents:
    corpus.append(sent.text)

nlp = spacy.blank("en")

ruler = nlp.add_pipe("entity_ruler")

patterns = [
                {"label": "GPE", "pattern": "Kirchstetten"}
            ]

ruler.add_patterns(patterns)

TRAIN_DATA = []
for sentence in corpus:
    doc = nlp(sentence)
    entities = []

    for ent in doc.ents:
        entities.append([ent.start_char, ent.end_char, ent.label_])
    TRAIN_DATA.append([sentence, {"entities": entities}])

# %%
print (TRAIN_DATA)
# Out:
# [['The Years in Austria . \n', {'entities': []}], ['Half an hour from the outskirts of  Vienna  an invisible \nthread bisect x s the motorway.  ', {'entities': []}], ['It leads from the church which \nlies to the north, more accurately speaking from the churchyard, \ndisregards entirely the traffic as it thunders to and from  the \ncapital , wriggles across a field to the south, passes a small \nhouse which was once a garage.  ', {'entities': []}], ["Up a steep path, plum trees \non one side and apple trees on the other, through a wicket \ngate, and now the thread, which has turned neither to right nor \nleft, has reached its objective:  a long, low house, more an \nextended workman's cottage.  ", {'entities': []}], ['Originally, the address was \nHinterhol 6 z 6 ;   later, the lane up from the village on the other \nside was renamed  Auden- A Strasse .  ', {'entities': []}], ['This thread or unseen line joins \nthe places where  Auden  prayed, sang (flat) and  was buried , and \nthe
# ...

# %%
import srsly
import typer
import warnings
from pathlib import Path

import spacy
from spacy.tokens import DocBin

def convert(lang: str, TRAIN_DATA, output_path: Path):
    nlp = spacy.blank(lang)
    db = DocBin()
    for text, annot in TRAIN_DATA:
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label)
            if span is None:
                msg = f"Skipping entity [{start}, {end}, {label}] in the following text because the character span '{doc.text[start:end]}' does not align with token boundaries:\n\n{repr(text)}\n"
                warnings.warn(msg)
            else:
                ents.append(span)
        doc.ents = ents
        db.add(doc)
    db.to_disk(output_path)

# %%
convert("en", TRAIN_DATA, "/content/gdrive/MyDrive/train.spacy")
convert("en", TRAIN_DATA, "/content/gdrive/MyDrive/valid.spacy")

# %%
# !python -m spacy init fill-config "/content/base_config.cfg" config.cfg
# Out:
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:445: UserWarning:
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy-cuda111, cupy-cuda11x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------
#
#   warnings.warn(f'''
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:445: UserWarning:
# ...

# %%
# !python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./valid.spacy --output ./output
# Out:
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:445: UserWarning:
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy-cuda111, cupy-cuda11x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------
#
#   warnings.warn(f'''
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:445: UserWarning:
# ...

# %%
# !python -m spacy train /content/config.cfg --output /content/output
# Out:
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:445: UserWarning:
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy-cuda111, cupy-cuda11x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------
#
#   warnings.warn(f'''
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:445: UserWarning:
# ...

# %%
trained_nlp = spacy.load("output/model-best")
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:887: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.5 and may not be 100% compatible with the current version (3.5.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
text = "Auden lived in Kirchstetten"
doc = trained_nlp(text)

for ent in doc.ents:
    print (ent.text, ent.label_)

# %%
print (ent.text, ent.label_)
# Out:
# Kirchstetten GPE

# %%
text = "Auden died in Vienna"
doc = trained_nlp(text)

for ent in doc.ents:
    print (ent.text, ent.label_)
if len(doc.ents) == 0:
    print ("No entities found.") #the model has been trained to identify only the word Kirchstetten as it is written now
# Out:
# No entities found.

# %% [markdown]
# Add a new entity in spacy

# %%
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
austria = nlp(open('Years_in_Austria.txt').read())
displacy.render(austria, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The Years in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Half an hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  from the outskirts of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vienna
# ...

# %%
import spacy
# load your model

from collections import Counter

ents = Counter()
for ent in nlp(austria).ents:
    ents[f"{ent.label_}:{ent.text}"] += 1

for key, val in ents.items():
    print(val, key, sep="\t")

#it count the appearance of the entities found in a doc
# Out:
# 20	GPE:Austria
# 1	TIME:Half an hour
# 23	GPE:Vienna
# 36	CARDINAL:one
# 1	PERSON:Hinterhol
# 3	CARDINAL:6
# 1	GPE:Strasse
# 128	PERSON:Auden
# 1	DATE:today
# 1	DATE:earlier days
# 2	PERSON:Frau Emma
# 1	LOC:Left
# 4	CARDINAL:2
# 3	PRODUCT:Wystan
# 22	NORP:Austrian
# 19	CARDINAL:two
# 1	PERSON:Sitzecke
# 1	ORG:Benson
# 2	PERSON:Lucia
# 1	GPE:Akenfield
# 3	WORK_OF_ART:Bible
# 2	DATE:the years
# 1	PERSON:Wohnkultur
# 6	GPE:Athens
# 3	PERSON:Stravinsky
# 1	PERSON:Richard Strauss
# 2	ORG:Times
# 1	ORG:Oxford English Dictionary
# 1	CARDINAL:thirteen
# 24	PERSON:Kirchstetten
# 2	DATE:Sunday
# 1	DATE:weekly
# 1	GPE:withou
# 1	PERSON:Wystan Auden
# 6	CARDINAL:3
# 3	WORK_OF_ART:Forewords and Afterwords
# 1	WORK_OF_ART:Oscar Wilde
# 1	PERSON:li
# 1	PERSON:Kurt Weill  records
# 1	DATE:winter
# 1	TIME:evening
# 57	PERSON:Chester
# 1	GPE:Esslarngasse
# 14	GPE:Wystan
# 2	PERSON:Tolkien
# 1	ORG:Rings
# 2	GPE:Tolkien
# 1	PERSON:trivi li
# 26	NORP:German
# 1	LOC:Lake of Constance
# 2	NORP:Austrians
# ...

# %% [markdown]
# Training Custom NER models in SpaCy to auto-detect named entities

# %%
# Load a spacy model and chekc if it has ner
import spacy
nlp=spacy.load('en_core_web_sm')

nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc = nlp(open('Years_in_Austria.txt').read())

# %% [markdown]
# Updating the Named Entity Recognizer

# %%
# Load pre-existing spacy model
import spacy
nlp=spacy.load('en_core_web_sm')

# Getting the pipeline component
ner=nlp.get_pipe("ner")

# %%
# training data
TRAIN_DATA = [
              ("Vienna is a city", {"entities": [(0, 6, "GPE")]}),
              ("I reached Kirchstetten yesterday.", {"entities": [(9, 23, "GPE")]}),
              ("I recently met with Chester", {"entities": [(20,27, "PERSON")]}),
              ("I was driving to Kirchstetten", {"entities": [(16,28, "GPE")]}),
              ("I kissed Mary", {"entities": [(10,13, "PERSON")]}),
              ("Chester left his keys", {"entities": [(0,7, "PERSON")]}),
              ("I visited Thessaloniki", {"entities": [(10,22, "GPE")]}),
              ("I travelled to Paris", {"entities": [(16,20, "GPE")]}),
              ("I talked to Peter", {"entities": [(11,16, "PERSON")]}),
              ("Oscar Wilde wrote a book", {"entities": [(0,11, "PERSON")]}),
              ("I met Lucas for a coffee", {"entities": [(5,10, "PERSON")]}),
              ("Amsterdam is not in my plans", {"entities": [(0,9, "GPE")]}),
              ("I book my tickets for London", {"entities": [(21,27, "GPE")]}),
              ("London is a city that never sleeps", {"entities": [(0,5, "GPE")]}),
              ("I invited John to come over", {"entities": [(10,14, "PERSON")]}),
              ("Mexico City has many inhabitants", {"entities": [(0,11, "GPE")]}),
              ("I recently got a call from Athens", {"entities": [(28,33, "GPE")]}),
              ("Paul has a nameday",{"entities": [(0,4, "PERSON")]}),
              ("I travelled to Rome", {"entities": [(16,19, "GPE")]}),
              ("Troy has a nameday", {"entities": [(0,4, "PERSON")]}),
              ("I met Bob on the street.", {"entities": [(6,9, "PERSON")]}),
              ("Sandra gave a speech.", {"entities": [(0,6, "PERSON")]}),
              ("Stephan called the police.", {"entities": [(0,7, "PERSON")]}),
              ("Stephan is famous.", {"entities": [(0,7, "PERSON")]})
              ]

# %%
# Adding labels to the `ner`

for _, annotations in TRAIN_DATA:
  for ent in annotations.get("entities"):
    ner.add_label(ent[2])

# %%
# Disable pipeline components we dont need to change
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
from spacy.training.example import Example

for batch in spacy.util.minibatch(TRAIN_DATA, size=2):
    for text, annotations in batch:
        # create Example
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, annotations)
        # Update the model
        nlp.update([example], losses=losses, drop=0.3)

# %%
# Testing the model
doc = nlp("Pedro is not famous.")
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('Pedro', 'PERSON')]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Save the  model to directory
output_dir = Path('/content/Trained_Model')
nlp.to_disk(output_dir)
print("Saved model to", output_dir)

# Load the saved model and predict
print("Loading from", output_dir)
nlp_updated = spacy.load(output_dir)
doc = nlp_updated("Maria met Noah for a coffee" )
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Saved model to /content/Trained_Model
# Loading from /content/Trained_Model
# Entities [('Maria', 'PERSON'), ('Noah', 'PERSON')]

# %%
doc = nlp_updated(open('Years_in_Austria.txt').read())

# %%
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The Years in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Half an hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  from the outskirts of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vienna
# ...
